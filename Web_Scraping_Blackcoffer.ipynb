# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Saurav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Put Output Data Structure file in the current working directory or put file path in brackets
df = pd.read_excel("Output Data Structure.xlsx")

# %% [markdown]
# # Reading stop words file and storing all stop words in one list

# %%
# Put Stop word files in the current working directory or put file path in brackets

stop_words_file_1 = open("StopWords_Auditor.txt", "r") 
stop_words_1 = stop_words_file_1.readlines()

stop_words_file_2 = open("StopWords_Currencies.txt", "r") 
stop_words_2 = stop_words_file_2.readlines()

stop_words_file_3 = open("StopWords_DatesandNumbers.txt", "r") 
stop_words_3 = stop_words_file_3.readlines()

stop_words_file_4 = open("StopWords_Generic.txt", "r") 
stop_words_4 = stop_words_file_4.readlines()

stop_words_file_5 = open("StopWords_GenericLong.txt", "r") 
stop_words_5 = stop_words_file_5.readlines()

stop_words_file_6 = open("StopWords_Geographic.txt", "r") 
stop_words_6 = stop_words_file_6.readlines()

stop_words_file_7 = open("StopWords_Names.txt", "r") 
stop_words_7 = stop_words_file_7.readlines()

# %%
for i in range( len(stop_words_1)): 
    stop_words_1[i] = stop_words_1[i][:-1]
for i in range(len(stop_words_2)):
    stop_words_2[i] = stop_words_2[i].split('|')[0].strip()
for i in range( len(stop_words_3)): 
    stop_words_3[i] = stop_words_3[i][:-1]
    stop_words_3[i] = stop_words_3[i].split('|')[0].strip()
for i in range( len(stop_words_4)): 
    stop_words_4[i] = stop_words_4[i][:-1]
for i in range( len(stop_words_5)): 
    stop_words_5[i] = stop_words_5[i][:-1]
for i in range( len(stop_words_6)): 
    stop_words_6[i] = stop_words_6[i][:-1]
    stop_words_6[i] = stop_words_6[i].split('|')[0].strip()
for i in range( len(stop_words_7)): 
    stop_words_7[i] = stop_words_7[i][:-1]
    stop_words_7[i] = stop_words_7[i].split('|')[0].strip()

stop_words = []
[stop_words.extend(x) for x in (stop_words_1,stop_words_2,stop_words_3,stop_words_4,stop_words_5,stop_words_6,stop_words_7)]
# Out:
# [None, None, None, None, None, None, None]

# %% [markdown]
# ## Reading Positive and Negative word file and storing in a list

# %%
# Put Positive word files in the current working directory or put file path in brackets

positive_words_file_1 = open("positive-words.txt", "r")
positive_words = positive_words_file_1.readlines()
for i in range( len(positive_words)): 
    positive_words[i] = positive_words[i][:-1]

# %%
# Put Negative word files in the current working directory or put file path in brackets

negative_words_file_1 = open("negative-words.txt", "r") 
negative_words = negative_words_file_1.readlines()
for i in range( len(negative_words)): 
    negative_words[i] = negative_words[i][:-1]

# %% [markdown]
# ### Syllable count function

# %%
def syllable_count(word):
    count = 0
    vowels = "aeiouy"
    if word[0] in vowels:
        count += 1
    for index in range(1, len(word)):
        if word[index] in vowels and word[index - 1] not in vowels:
            count += 1
            if word.endswith("e"):
                count -= 1
    if count == 0:
        count += 1
    return count

# %% [markdown]
# ### extract_article function for extracting title and content from url

# %%
def extract_article(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Extract the article title
            title = soup.find('h1')
            if title:
                title_text = title.text
            else:
                title_text = "Title not found"
            
            article_content = soup.find('div', class_ = "td-post-content")
            if article_content:
                content = article_content.text
            else:
                content = "Content not found"
            
            return title_text, content
        else:
            return None, None
    except Exception as e:
        print(f"Error scraping {url}: {e}")
        return None, None

# %% [markdown]
# ### URLS is a list containing all urls
# ##### NOTE: below cell will take a liitle longer time to execute

# %%
URLS = ["https://insights.blackcoffer.com/rising-it-cities-and-its-impact-on-the-economy-environment-infrastructure-and-city-life-by-the-year-2040-2/","https://insights.blackcoffer.com/rising-it-cities-and-their-impact-on-the-economy-environment-infrastructure-and-city-life-in-future/","https://insights.blackcoffer.com/internet-demands-evolution-communication-impact-and-2035s-alternative-pathways/","https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-in-upcoming-future/","https://insights.blackcoffer.com/ott-platform-and-its-impact-on-the-entertainment-industry-in-future/","https://insights.blackcoffer.com/the-rise-of-the-ott-platform-and-its-impact-on-the-entertainment-industry-by-2040/","https://insights.blackcoffer.com/rise-of-cyber-crime-and-its-effects/","https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035-2/","https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040-2/","https://insights.blackcoffer.com/rise-of-cybercrime-and-its-effect-by-the-year-2040/","https://insights.blackcoffer.com/rise-of-internet-demand-and-its-impact-on-communications-and-alternatives-by-the-year-2035/","https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-3-2/","https://insights.blackcoffer.com/rise-of-e-health-and-its-impact-on-humans-by-the-year-2030/","https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030-2/","https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2/","https://insights.blackcoffer.com/rise-of-telemedicine-and-its-impact-on-livelihood-by-2040-2-2/","https://insights.blackcoffer.com/rise-of-chatbots-and-its-impact-on-customer-support-by-the-year-2040/","https://insights.blackcoffer.com/rise-of-e-health-and-its-imapct-on-humans-by-the-year-2030/","https://insights.blackcoffer.com/how-does-marketing-influence-businesses-and-consumers/","https://insights.blackcoffer.com/how-advertisement-increase-your-market-value/","https://insights.blackcoffer.com/negative-effects-of-marketing-on-society/","https://insights.blackcoffer.com/how-advertisement-marketing-affects-business/","https://insights.blackcoffer.com/rising-it-cities-will-impact-the-economy-environment-infrastructure-and-city-life-by-the-year-2035/","https://insights.blackcoffer.com/rise-of-ott-platform-and-its-impact-on-entertainment-industry-by-the-year-2030/","https://insights.blackcoffer.com/rise-of-electric-vehicles-and-its-impact-on-livelihood-by-2040/","https://insights.blackcoffer.com/rise-of-electric-vehicle-and-its-impact-on-livelihood-by-the-year-2040/","https://insights.blackcoffer.com/oil-prices-by-the-year-2040-and-how-it-will-impact-the-world-economy/","https://insights.blackcoffer.com/an-outlook-of-healthcare-by-the-year-2040-and-how-it-will-impact-human-lives/","https://insights.blackcoffer.com/ai-in-healthcare-to-improve-patient-outcomes/","https://insights.blackcoffer.com/what-if-the-creation-is-taking-over-the-creator/","https://insights.blackcoffer.com/what-jobs-will-robots-take-from-humans-in-the-future/","https://insights.blackcoffer.com/will-machine-replace-the-human-in-the-future-of-work/","https://insights.blackcoffer.com/will-ai-replace-us-or-work-with-us/","https://insights.blackcoffer.com/man-and-machines-together-machines-are-more-diligent-than-humans-blackcoffe/","https://insights.blackcoffer.com/in-future-or-in-upcoming-years-humans-and-machines-are-going-to-work-together-in-every-field-of-work/","https://insights.blackcoffer.com/how-neural-networks-can-be-applied-in-various-areas-in-the-future
://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-sports-events-around-the-world/","https://insights.blackcoffer.com/changing-landscape-and-emerging-trends-in-the-indian-it-ites-industry/","https://insights.blackcoffer.com/online-gaming-adolescent-online-gaming-effects-demotivated-depression-musculoskeletal-and-psychosomatic-symptoms/","https://insights.blackcoffer.com/human-rights-outlook/","https://insights.blackcoffer.com/how-voice-search-makes-your-business-a-successful-business/","https://insights.blackcoffer.com/how-the-covid-19-crisis-is-redefining-jobs-and-services/","https://insights.blackcoffer.com/how-to-increase-social-media-engagement-for-marketers/","https://insights.blackcoffer.com/impacts-of-covid-19-on-streets-sides-food-stalls/","https://insights.blackcoffer.com/coronavirus-impact-on-energy-markets-2/","https://insights.blackcoffer.com/coronavirus-impact-on-the-hospitality-industry-5/","https://insights.blackcoffer.com/lessons-from-the-past-some-key-learnings-relevant-to-the-coronavirus-crisis-4/","https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-2/","https://insights.blackcoffer.com/estimating-the-impact-of-covid-19-on-the-world-of-work-3/","https://insights.blackcoffer.com/travel-and-tourism-outlook/","https://insights.blackcoffer.com/gaming-disorder-and-effects-of-gaming-on-health/","https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation/","https://insights.blackcoffer.com/what-is-the-repercussion-of-the-environment-due-to-the-covid-19-pandemic-situation-2/","https://insights.blackcoffer.com/impact-of-covid-19-pandemic-on-office-space-and-co-working-industries/","https://insights.blackcoffer.com/contribution-of-handicrafts-visual-arts-literature-in-the-indian-economy/","https://insights.blackcoffer.com/how-covid-19-is-impacting-payment-preferences/","https://insights.blackcoffer.com/how-will-covid-19-affect-the-world-of-work-2/"]
row = 0
for url in URLS:
    # Extract article title and content
    title, content = extract_article(url)
    if content == None:         # for invailid url which give error
        df.iloc[row,2:15] = "invalid url"
        row += 1
        continue
    article_tokenize_words = [item for item in word_tokenize(content) if str(item).isalnum()]
    article_tokenize_sentence = sent_tokenize(content)

    article_tokenize_words_without_stop_words = []   # list for article words without having stop words
    for word in article_tokenize_words:
        if word not in stop_words:
            article_tokenize_words_without_stop_words.append(word)
            
    POSITIVE_SCORE =0
    for word in article_tokenize_words_without_stop_words:
        if word in positive_words:
            POSITIVE_SCORE = POSITIVE_SCORE + 1
            
    NEGATIVE_SCORE =0
    for word in article_tokenize_words_without_stop_words:
        if word in negative_words:
            NEGATIVE_SCORE = NEGATIVE_SCORE + 1
            
    Polarity_Score = (POSITIVE_SCORE - NEGATIVE_SCORE)/ ((POSITIVE_SCORE + NEGATIVE_SCORE) + 0.000001)
    Subjectivity_Score = (POSITIVE_SCORE + NEGATIVE_SCORE)/ ((len(article_tokenize_words_without_stop_words)) + 0.000001)
    Average_Sentence_Length = int(len(article_tokenize_words) / len(article_tokenize_sentence))
    
    COMPLEX_WORD_COUNT =0
    for word in article_tokenize_words:
        if syllable_count(word) > 2:
            COMPLEX_WORD_COUNT += 1
            
    PERCENTAGE_OF_COMPLEX_WORDS = COMPLEX_WORD_COUNT/ len(article_tokenize_words)*100
    FOG_INDEX = 0.4*(Average_Sentence_Length + PERCENTAGE_OF_COMPLEX_WORDS)
    
    Total_Syllable = 0
    for word in article_tokenize_words:
        x = syllable_count(word)
        Total_Syllable += x
        
    SYLLABLE_PER_WORD = Total_Syllable/len(article_tokenize_words)
    
    PRONOUNS = ["I","i","we","We", "my","My", "ours","Ours","Us", "us"]
    PERSONAL_PRONOUNS = 0
    total_number_of_characters = 0
    for word in article_tokenize_words:
        total_number_of_characters += len(word) 
        if word in PRONOUNS:
            PERSONAL_PRONOUNS += 1
            
    AVG_WORD_LENGTH = total_number_of_characters / len(article_tokenize_words)
    
    df.at[row, 'POSITIVE SCORE'] = POSITIVE_SCORE
    df.at[row, 'NEGATIVE SCORE'] = NEGATIVE_SCORE
    df.at[row, 'POLARITY SCORE'] = Polarity_Score
    df.at[row, 'SUBJECTIVITY SCORE'] = Subjectivity_Score
    df.at[row, 'AVG SENTENCE LENGTH'] = Average_Sentence_Length
    df.at[row, 'PERCENTAGE OF COMPLEX WORDS'] = PERCENTAGE_OF_COMPLEX_WORDS
    df.at[row, 'FOG INDEX'] = FOG_INDEX
    df.at[row, 'AVG NUMBER OF WORDS PER SENTENCE'] = Average_Sentence_Length
    df.at[row, 'COMPLEX WORD COUNT'] = int(COMPLEX_WORD_COUNT)
    df.at[row, 'WORD COUNT'] = len(article_tokenize_words_without_stop_words)
    df.at[row, 'SYLLABLE PER WORD'] = SYLLABLE_PER_WORD
    df.at[row, 'PERSONAL PRONOUNS'] = PERSONAL_PRONOUNS
    df.at[row, 'AVG WORD LENGTH'] = AVG_WORD_LENGTH
    row += 1

# %%
df.head(50)
# Out:
#              URL_ID                                                URL  \
# 0   blackassign0001  https://insights.blackcoffer.com/rising-it-cit...
# 1   blackassign0002  https://insights.blackcoffer.com/rising-it-cit...
# 2   blackassign0003  https://insights.blackcoffer.com/internet-dema...
# 3   blackassign0004  https://insights.blackcoffer.com/rise-of-cyber...
# 4   blackassign0005  https://insights.blackcoffer.com/ott-platform-...
# 5   blackassign0006  https://insights.blackcoffer.com/the-rise-of-t...
# 6   blackassign0007  https://insights.blackcoffer.com/rise-of-cyber...
# 7   blackassign0008  https://insights.blackcoffer.com/rise-of-inter...
# 8   blackassign0009  https://insights.blackcoffer.com/rise-of-cyber...
# 9   blackassign0010  https://insights.blackcoffer.com/rise-of-cyber...
# 10  blackassign0011  https://insights.blackcoffer.com/rise-of-inter...
# 11  blackassign0012  https://insights.blackcoffer.com/rise-of-telem...
# 12  blackassign0013  https://insights.blackcoffer.com/rise-of-e-hea...
# 13  blackassign0014  https://insights.blackcoffer.com/rise-of-e-hea...
# 14  blackassign0015  https://insights.blackcoffer.com/rise-of-telem...
# 15  blackassign0016  https://insights.blackcoffer.com/rise-of-telem...
# 16  blackassign0017  https://insights.blackcoffer.com/rise-of-chatb...
# 17  blackassign0018  https://insights.blackcoffer.com/rise-of-e-hea...
# 18  blackassign0019  https://insights.blackcoffer.com/how-does-mark...
# 19  blackassign0020  https://insights.blackcoffer.com/how-advertise...
# 20  blackassign0021  https://insights.blackcoffer.com/negative-effe...
# 21  blackassign0022  https://insights.blackcoffer.com/how-advertise...
# 22  blackassign0023  https://insights.blackcoffer.com/rising-it-cit...
# 23  blackassign0024  https://insights.blackcoffer.com/rise-of-ott-p...
# 24  blackassign0025  https://insights.blackcoffer.com/rise-of-elect...
# 25  blackassign0026  https://insights.blackcoffer.com/rise-of-elect...
# 26  blackassign0027  https://insights.blackcoffer.com/oil-prices-by...
# 27  blackassign0028  https://insights.blackcoffer.com/an-outlook-of...
# 28  blackassign0029  https://insights.blackcoffer.com/ai-in-healthc...
# 29  blackassign0030  https://insights.blackcoffer.com/what-if-the-c...
# 30  blackassign0031  https://insights.blackcoffer.com/what-jobs-wil...
# 31  blackassign0032  https://insights.blackcoffer.com/will-machine-...
# 32  blackassign0033  https://insights.blackcoffer.com/will-ai-repla...
# 33  blackassign0034  https://insights.blackcoffer.com/man-and-machi...
# 34  blackassign0035  https://insights.blackcoffer.com/in-future-or-...
# 35  blackassign0036  https://insights.blackcoffer.com/how-neural-ne...
# 36  blackassign0037  https://insights.blackcoffer.com/how-machine-l...
# 37  blackassign0038  https://insights.blackcoffer.com/deep-learning...
# 38  blackassign0039  https://insights.blackcoffer.com/how-to-protec...
# 39  blackassign0040  https://insights.blackcoffer.com/how-machines-...
# 40  blackassign0041  https://insights.blackcoffer.com/ai-human-robo...
# 41  blackassign0042  https://insights.blackcoffer.com/how-ai-will-c...
# 42  blackassign0043  https://insights.blackcoffer.com/future-of-wor...
# 43  blackassign0044  https://insights.blackcoffer.com/ai-tool-alexa...
# 44  blackassign0045  https://insights.blackcoffer.com/ai-healthcare...
# 45  blackassign0046  https://insights.blackcoffer.com/all-you-need-...
# 46  blackassign0047  https://insights.blackcoffer.com/evolution-of-...
# 47  blackassign0048  https://insights.blackcoffer.com/how-data-anal...
# 48  blackassign0049  https://insights.blackcoffer.com/covid-19-envi...
# 49  blackassign0050  https://insights.blackcoffer.com/environmental...
#
#    POSITIVE SCORE NEGATIVE SCORE POLARITY SCORE SUBJECTIVITY SCORE  \
# 0            33.0              5       0.736842           0.060703
# 1            56.0             31       0.287356           0.106227
# 2            37.0             23       0.233333           0.092166
# 3            34.0             71      -0.352381           0.165615
# 4            21.0              8       0.448276           0.081461
# 5            83.0             23       0.566038           0.097159
# 6            30.0             60      -0.333333           0.123967
# 7            26.0              9       0.485714           0.071575
# 8            35.0             49      -0.166667           0.135484
# 9           135.0            173      -0.123377               0.16
# 10           60.0             19       0.518987           0.093936
# 11           76.0             24           0.52           0.110254
# 12           38.0             13       0.490196           0.171717
# 13           19.0             27      -0.173913           0.080279
# 14           33.0             27            0.1           0.089552
# 15           33.0             27            0.1           0.089552
# 16           45.0             10       0.636364           0.086342
# 17           32.0             10        0.52381             0.0746
# 18           56.0              6       0.806452           0.068207
# 19            8.0              0            1.0           0.034934
# 20           20.0             44         -0.375           0.117431
# 21           12.0              9       0.142857           0.106599
# 22           28.0             14       0.333333           0.060432
# 23           21.0              3           0.75           0.083333
# 24           17.0              9       0.307692           0.050682
# 25           23.0             14       0.243243           0.074747
# 26           23.0             24      -0.021277           0.078333
# 27           30.0             25       0.090909           0.098921
# 28           63.0             33         0.3125           0.093933
# 29           56.0             37       0.204301           0.145997
# 30           66.0             33       0.333333           0.107961
# 31           57.0             25       0.390244           0.110067
# 32           49.0             24       0.342466           0.084101
# 33           43.0             23        0.30303           0.106109
# 34           25.0             12       0.351351            0.09973
# 35    invalid url    invalid url    invalid url        invalid url
# 36             37             13           0.48           0.134048
# 37             64             40       0.230769           0.105263
# 38             46             64      -0.163636           0.105769
# 39             34             19       0.283019           0.082812
# 40             27             24       0.058824           0.079193
# 41             60             24       0.428571           0.120344
# 16                             17.0              244.0        637.0
# 17                             22.0              221.0        563.0
# 18                             18.0              369.0        909.0
# 19                             20.0               74.0        229.0
# 20                             20.0              230.0        545.0
# 21                             15.0               64.0        197.0
# 22                             21.0              191.0        695.0
# 23                             26.0              106.0        288.0
# 24                             38.0              118.0        513.0
# 25                             21.0              157.0        495.0
# 26                             24.0              174.0        600.0
# 27                             27.0              187.0        556.0
# 28                             23.0              400.0       1022.0
# 29                             17.0              213.0        637.0
# 30                             20.0              365.0        917.0
# 31                             17.0              206.0        745.0
# 32                             21.0              267.0        868.0
# 33                             20.0              207.0        622.0
# 34                             16.0              129.0        371.0
# 35                      invalid url        invalid url  invalid url
# 36                               20                 82          373
# 37                               26                340          988
# 38                               19                307         1040
# 39                               20                252          640
# 40                               14                199          644
# 41                               26                241          698
# 42                               19                260          802
# 43                               22                 88          265
# 44                              202                236          722
# 45                               17                183          511
# 46                               17                177          385
# 47                               25                 68          153
# 48                      invalid url        invalid url  invalid url
# 49                               24                224          712
#
#    SYLLABLE PER WORD PERSONAL PRONOUNS AVG WORD LENGTH
# 0           1.467159              11.0        4.574713
# 1           1.741096               4.0        5.367808
# 2           1.907707              13.0        6.034253
# 3           1.826996               5.0        5.914449
# 4           1.648729               6.0        5.405082
# 5           1.845179               6.0         5.89697
# 6           1.657588               1.0        5.207782
# 7           1.973369               3.0        6.210386
# 8            1.96688               3.0        6.253205
# 9           1.677086              13.0        5.330253
# 10          1.793103               3.0        5.753695
# 11          1.583836               2.0         5.54222
# 12          1.691152               3.0        5.414023
# 13          1.652751               3.0        5.195446
# 14          1.681555               7.0        5.408602
# 15          1.681555               7.0        5.408602
# 16          1.716899               3.0        5.446864
# 17          1.703922               1.0        5.435294
# 18          1.674378               5.0        5.231348
# 19          1.540892               1.0        4.964684
# 20          1.745311               6.0        5.508391
# 21          1.591346               5.0        4.920673
# 22           1.57489               7.0        4.946402
# 23           1.64652               1.0        5.173993
# 24          1.476143               4.0        4.626243
# 25          1.617783               1.0        5.128176
# 26          1.473404              26.0        4.537994
# 27          1.587793               9.0        5.210329
# 28           1.77301               1.0        5.540373
# 29          1.523338               6.0        4.742574
# 30          1.742068               3.0        5.360752
# 31          1.472273              17.0        4.762949
# 32          1.557548              16.0        4.990168
# 33          1.572537              21.0        4.960434
# 34          1.566713               7.0        4.982118
# 35       invalid url       invalid url     invalid url
# 36          1.421341                 2        4.694938
# 37          1.566029                11        4.815679
# 38          1.564386                 0        4.985412
# 39          1.708615                10        5.460304
# 40          1.564437                 6        4.916803
# 41          1.516477                22        4.788496
# 42          1.569597                11        4.993284
# 43          1.636364                 0        5.339394
# 44          1.463776                15        4.672887
# 45          1.610294                 0        5.128151
# 46          1.783404                 1         5.38256
# 47          1.716129                 2        5.306452
# 48       invalid url       invalid url     invalid url
# 49          1.600147                 2        5.040501

# %%
df.to_csv("Output_Data_Structure_Result.csv",index=False)
